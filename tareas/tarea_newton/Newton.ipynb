# %%
from intervalo import *
import numpy as np

# %% [markdown]
# Funciones a utilizar:

# %%
def g(x) :
    return (x**2 - 4)

def g_p(x) :
    return 2*x
    
def h(x) :
    # return x*x*x - 3*x*x + 2*x
    # return x*np.exp(x) - 1
    # return 4*x**3 - 2*x
    return 0.5*np.sin(x)

def h_p(x) :
    def hh_p(x):
        # return 3*x*x - 6*x + 2
        # return np.exp(x)*x + np.exp(x)
        # return 12*x**2 - 2
        return 0.5*np.cos(x)
    
    n = 1000
    epsilon = float(x.hi - x.lo)/n
    current_x = x.lo
    
    for i in range(1,n) :
        micro_x = Intervalo(current_x, current_x + epsilon)
        current_x += epsilon
        
        this_y = hh_p(micro_x)
        if i == 1 :
            y_final = this_y
        else:
            y_final = Intervalo.hull(y_final, this_y)
        
    return y_final

# %% [markdown]
# Método de Newton para intervalos. Se hicieron modificaciones a la clase de intervalo para poder devolver una lista de intervalos para cuando se quiera calcular el recíproco de un intervalo que contenga el cero. El método no funciona todo el tiempo, y esto es debido a que si se escoge un intervalo muy grande o si se escoge una función de un orden muy alto el error aumenta tanto que el algoritmo encuentra más zonas donde $F'([x]) = 0$ que las que en verdad existen.

# %%
def met_newton(x, f, f_p, steps = 10000, epsilon = 1e-5) :
    # x       - intervalo
    # f       - función
    # f_p     - derivada de la función f
    # steps   - número máximo de iteraciones
    # epsilon - tolerancia para encontrar la raíz
    
    ceros = []
    intervalos = [x]
    index = 0
    terminar_ciclo = False
    
    while index < steps :
        
        cuenta_tolerancia = 0
        nuevos_intervalos = []
        
        for x in intervalos :
            if 0 in f_p(x) and (f_p(x).lo != 0 and f_p(x).hi != 0):
                # el reciproco de f_p(x) va a devolver 2 intervalos
                
                x_1 = x & (x.middle() - f(x.middle())*f_p(x).reciprocal()[0])
                x_2 = x & (x.middle() - f(x.middle())*f_p(x).reciprocal()[1])
                
                # print "hey corte ", x
                
                if not isinstance(x_1, Intervalo) and not isinstance(x_2, Intervalo):
                    nuevos_intervalos.append(x)
                else :
                    if x_1 in x :
                        # print "inclui x_1", x_1
                        nuevos_intervalos.append(x_1) 
                    if x_2 in x :
                        # print "inclui x_2", x_2
                        nuevos_intervalos.append(x_2)
            else :
                x_new = x & (x.middle() - f(x.middle())*f_p(x).reciprocal())
                if not isinstance(x_new, Intervalo) :
                    x_new = x
                if x_new in x:
                    # print "no corte", x, "e inclui x_new", x_new
                    nuevos_intervalos.append(x_new)
        
        nuevos_intervalos[:] = (value for value in nuevos_intervalos if isinstance(value, Intervalo))
        for x_new in nuevos_intervalos :
            if abs(x_new.width()) < epsilon :
                cuenta_tolerancia += 1
                
        if cuenta_tolerancia == len(nuevos_intervalos) :
            intervalos = nuevos_intervalos
            terminar_ciclo = True
        
        # print "antes:", intervalos
        intervalos = nuevos_intervalos
        # print "despues", intervalos
        # print "fin de vuelta"
        
        
        if terminar_ciclo == True :
            break
        index += 1    
    ceros = intervalos
    return ceros

# %% [markdown]
# Para este caso se analizará $f(x) = 0.5 \sin(x)$, con el intervalo $[x] = [0,10]$

# %%
met_newton(Intervalo(0,10),h,h_p,10,1e-10)
# Out:
# Advertencia: El reciproco devuelve la uni�n de m�s de un intervalo en forma de una lista
# Advertencia: El reciproco devuelve la uni�n de m�s de un intervalo en forma de una lista
# Advertencia: El reciproco devuelve la uni�n de m�s de un intervalo en forma de una lista
# Advertencia: El reciproco devuelve la uni�n de m�s de un intervalo en forma de una lista
# Advertencia: El reciproco devuelve la uni�n de m�s de un intervalo en forma de una lista
# Advertencia: El reciproco devuelve la uni�n de m�s de un intervalo en forma de una lista
# [Intervalo [3.14159265359,3.14159265359],
#  Intervalo [0,0.0],
#  Intervalo [9.42477796077,9.42477796077],
#  Intervalo [6.28318530718,6.28318530718]]

# %% [markdown]
# Lo cual tiene totalmente sentido. Pues podemos ver en la siguiente gráfica que todos estos valores son múltiplos enteros de $\pi$

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
x = np.linspace(0, 10, 101)
y = 0.5*np.sin(x)
plt.plot(x,y)
plt.grid()

# %% [markdown]
# Probemos con un polinomio:

# %%
def h(x) :
    return 4*x**3 - 2*x

def h_p(x) :
    def hh_p(x):
        return 12*x**2 - 2
    
    n = 1000
    epsilon = float(x.hi - x.lo)/n
    current_x = x.lo
    
    for i in range(1,n) :
        micro_x = Intervalo(current_x, current_x + epsilon)
        current_x += epsilon
        
        this_y = hh_p(micro_x)
        if i == 1 :
            y_final = this_y
        else:
            y_final = Intervalo.hull(y_final, this_y)
        
    return y_final

# %%
met_newton(Intervalo(0,10),h,h_p,10,1e-10)
# Out:
# Advertencia: El intervalo contiene el cero
# Advertencia: El intervalo contiene el cero
# Advertencia: El intervalo contiene el cero
# Advertencia: El intervalo contiene el cero
# Advertencia: El reciproco devuelve la uni�n de m�s de un intervalo en forma de una lista
# Advertencia: El intervalo contiene el cero
# Advertencia: El reciproco devuelve la uni�n de m�s de un intervalo en forma de una lista
# Advertencia: El intervalo contiene el cero
# Advertencia: El intervalo contiene el cero
# Advertencia: El intervalo contiene el cero
# Advertencia: El intervalo contiene el cero
# Advertencia: El reciproco devuelve la uni�n de m�s de un intervalo en forma de una lista
# Advertencia: El intervalo contiene el cero
# Advertencia: El reciproco devuelve la uni�n de m�s de un intervalo en forma de una lista
# Advertencia: El intervalo contiene el cero
# Advertencia: El intervalo contiene el cero
# Advertencia: El intervalo contiene el cero
# Advertencia: El intervalo contiene el cero
# ...

# %%
y = 4*x**3 - 2*x
plt.plot(x,y)
plt.axis([0,2,-1,10])
plt.grid()

# %% [markdown]
# Que como podemos ver nos devuelve las raíces correctas, pues éstas deben ser $\frac{-1}{\sqrt 2},0,\frac{1}{\sqrt 2}$ y aquí sólo incluimos el intervalo de $[x] = [0,10]$, por lo que no obtendremos la primera raíz.

# %%
def h(x) :
    return x*np.exp(x) - 1

def h_p(x) :
    def hh_p(x):
        return np.exp(x)*x + np.exp(x)
    
    n = 1000
    epsilon = float(x.hi - x.lo)/n
    current_x = x.lo
    
    for i in range(1,n) :
        micro_x = Intervalo(current_x, current_x + epsilon)
        current_x += epsilon
        
        this_y = hh_p(micro_x)
        if i == 1 :
            y_final = this_y
        else:
            y_final = Intervalo.hull(y_final, this_y)
        
    return y_final

# %% [markdown]
# Por último probemos para la función $f(x) = x \exp(x)  - 1$ que su raíz es $x_{0} \approx 0.567143$

# %%
met_newton(Intervalo(0,10),h,h_p,10,1e-10)
# Out:
# [Intervalo [0.56714329041,0.56714329041]]

# %% [markdown]
# Genial. Claro que hay ejemplos en los cuales el método no regresará las raíces que uno esperaría (como mencioné, debido a que la aritmética de intervalos para polinimos de orden muy alto tiende a "repetir" intervalos donde $F'([x]) = 0$. Para evitar eso se sugiere tratar de estudiar el comportamiento de la función gráficamente y tratar de establecer un intervalo de búsqueda más práctico.
