# %% [markdown]
# # Tarea 1: Ejercicios de calentamiento con Python

# %% [markdown]
# **REGLAS:**
#
# - Usa Python para llevar a cabo las tareas. [O julia...]
#
# - Sí se permite el trabajo colaborativo, y de hecho se fomenta, pero se exige el uso de las neuronas de todos los que colaboren. Se vale entregar una sola tarea por grupo de 2 o (si es necesario) 3 personas.
#
# - La tarea se entrega como un *notebook* de IPython, y debe incluir notas, comentario y **TODO** lo estéticamente necesario, que lo haga entendible para una tercer persona no involucrada en el curso.
#
# - Se recomienda usar una versión nueva de este mismo notebook, reemplazando *[Respuesta aquí] por tu discusión, código, y resultados (en los tipos de celda que convengan, y con el número de ellos que haga falta).
#
# - Cambia el nombre del notebook para reflejar el nombre que escojan para su grupo de trabajo, e.g. "Tarea-01-profes"

# %% [markdown]
# **1.** Implementa (con Python) el llamado "método Babilónico" para calcular la raíz cuadrada de un
# número dado, $y$. Este método consiste en la iteración
# $ x_{n+1} = \frac{1}{2} ( x_n + \frac{y}{x_n}). $
#
# a. ¿Cuándo se debería terminar la iteracion?
#
# b. ¿Cuál es la convergencia del método?
#
# c. Calcula, usando este método, la raíz cuadrada de los números $0$ hasta $10$, en pasos de $0.1$.
#
# d. ¿Qué sería bueno "poder hacer" --y que aún no hemos aprendido-- con este código para poderlo correr muchas veces sin tener que incluirlo explícitamente?

# %% [markdown]
# ### Respuestas al problema 1

# %% [markdown]
# a) Se debe de fijar un "error" para terminar la iteración. En mi caso decidí que la raíz debe de tener 8 dígitos significativos para terminar.

# %% [markdown]
# b) En la práctica se obtuvo que el método sólo converge cuando los valores de $x_0$ y la raíz son positivos. Fuera de ese caso el método converge para el valor de la raíz buscada.

# %% [markdown]
# c) Después de correr el método como se pide se obtuvieron los siguientes resultados:

# %% [raw]
# La raiz de  0  es  0
# La raiz de  0.1  es  0.316227766017
# La raiz de  0.2  es  0.4472135955
# La raiz de  0.3  es  0.547722557505
# La raiz de  0.4  es  0.632455532034
# La raiz de  0.5  es  0.707106781187
# La raiz de  0.6  es  0.774596669241
# La raiz de  0.7  es  0.836660026534
# La raiz de  0.8  es  0.894427191
# La raiz de  0.9  es  0.948683298051
# La raiz de  1.0  es  1.0
# La raiz de  1.1  es  1.04880884817
# La raiz de  1.2  es  1.09544511501
# La raiz de  1.3  es  1.1401754251
# La raiz de  1.4  es  1.18321595662
# La raiz de  1.5  es  1.22474487139
# La raiz de  1.6  es  1.26491106407
# La raiz de  1.7  es  1.30384048104
# La raiz de  1.8  es  1.3416407865
# La raiz de  1.9  es  1.37840487521
# La raiz de  2.0  es  1.41421356237
# La raiz de  2.1  es  1.44913767462
# La raiz de  2.2  es  1.48323969742
# La raiz de  2.3  es  1.51657508881
# La raiz de  2.4  es  1.54919333848
# La raiz de  2.5  es  1.58113883008
# La raiz de  2.6  es  1.61245154966
# La raiz de  2.7  es  1.64316767252
# La raiz de  2.8  es  1.67332005307
# La raiz de  2.9  es  1.70293863659
# La raiz de  3.0  es  1.73205080757
# La raiz de  3.1  es  1.76068168617
# La raiz de  3.2  es  1.788854382
# La raiz de  3.3  es  1.81659021246
# La raiz de  3.4  es  1.84390889146
# La raiz de  3.5  es  1.87082869339
# La raiz de  3.6  es  1.8973665961
# La raiz de  3.7  es  1.92353840617
# La raiz de  3.8  es  1.94935886896
# La raiz de  3.9  es  1.97484176581
# La raiz de  4.0  es  2.0
# La raiz de  4.1  es  2.02484567313
# La raiz de  4.2  es  2.04939015319
# La raiz de  4.3  es  2.07364413533
# La raiz de  4.4  es  2.09761769634
# La raiz de  4.5  es  2.12132034356
# La raiz de  4.6  es  2.14476105895
# La raiz de  4.7  es  2.16794833887
# La raiz de  4.8  es  2.19089023002
# La raiz de  4.9  es  2.21359436212
# La raiz de  5.0  es  2.2360679775
# La raiz de  5.1  es  2.25831795813
# La raiz de  5.2  es  2.2803508502
# La raiz de  5.3  es  2.30217288664
# La raiz de  5.4  es  2.32379000772
# La raiz de  5.5  es  2.34520787991
# La raiz de  5.6  es  2.36643191324
# La raiz de  5.7  es  2.38746727726
# La raiz de  5.8  es  2.40831891576
# La raiz de  5.9  es  2.4289915603
# La raiz de  6.0  es  2.44948974278
# La raiz de  6.1  es  2.46981780705
# La raiz de  6.2  es  2.4899799196
# La raiz de  6.3  es  2.5099800796
# La raiz de  6.4  es  2.52982212813
# La raiz de  6.5  es  2.5495097568
# La raiz de  6.6  es  2.56904651573
# La raiz de  6.7  es  2.58843582111
# La raiz de  6.8  es  2.60768096208
# La raiz de  6.9  es  2.62678510731
# La raiz de  7.0  es  2.64575131106
# La raiz de  7.1  es  2.66458251889
# La raiz de  7.2  es  2.683281573
# La raiz de  7.3  es  2.70185121722
# La raiz de  7.4  es  2.72029410175
# La raiz de  7.5  es  2.73861278753
# La raiz de  7.6  es  2.75680975042
# La raiz de  7.7  es  2.7748873851
# La raiz de  7.8  es  2.79284800875
# La raiz de  7.9  es  2.81069386451
# La raiz de  8.0  es  2.82842712475
# La raiz de  8.1  es  2.84604989415
# La raiz de  8.2  es  2.86356421266
# La raiz de  8.3  es  2.88097205818
# La raiz de  8.4  es  2.89827534924
# La raiz de  8.5  es  2.91547594742
# La raiz de  8.6  es  2.93257565972
# La raiz de  8.7  es  2.94957624075
# La raiz de  8.8  es  2.96647939484
# La raiz de  8.9  es  2.98328677804
# La raiz de  9.0  es  3.0
# La raiz de  9.1  es  3.0166206258
# La raiz de  9.2  es  3.03315017762
# La raiz de  9.3  es  3.0495901364
# La raiz de  9.4  es  3.06594194335
# La raiz de  9.5  es  3.08220700148
# La raiz de  9.6  es  3.09838667697
# La raiz de  9.7  es  3.11448230048
# La raiz de  9.8  es  3.1304951685
# La raiz de  9.9  es  3.14642654451
# La raiz de  10.0  es  3.16227766017

# %% [markdown]
# d) Supongo que se refiere a usar el método como una función. Para eso es necesario agregarla en el código, tal y como se hizo en este caso en la función raiz().

# %% [markdown]
# ### Código del problema 1

# %%
import numpy as np

def raiz(y):
	error = 1E-8;	#8 decimales significativos
	x0 = y/2.0		#semilla siendo la mitad del valor a buscar
	x1 = y
	while (np.abs(x1-x0) > error):
		x0 = x1
		x1 = 1/2.0*(x0+y/x0)
	return x1

#generador obtenido de internet, permite iterar dando un incio, 
#fin y un 'paso' (al igual que en MATLAB)
def my_range(start, end, step):
    while start <= end:
        yield start
        start += step

#impresion de las raices entre 0 y 10 a intervalos de 0.1
for i in my_range(0,10,0.1):
	print "La raiz de ", i , " es ", raiz(i)
# Out:
# La raiz de  0  es  0
# La raiz de  0.1  es  0.316227766017
# La raiz de  0.2  es  0.4472135955
# La raiz de  0.3  es  0.547722557505
# La raiz de  0.4  es  0.632455532034
# La raiz de  0.5  es  0.707106781187
# La raiz de  0.6  es  0.774596669241
# La raiz de  0.7  es  0.836660026534
# La raiz de  0.8  es  0.894427191
# La raiz de  0.9  es  0.948683298051
# La raiz de  1.0  es  1.0
# La raiz de  1.1  es  1.04880884817
# La raiz de  1.2  es  1.09544511501
# La raiz de  1.3  es  1.1401754251
# La raiz de  1.4  es  1.18321595662
# La raiz de  1.5  es  1.22474487139
# La raiz de  1.6  es  1.26491106407
# La raiz de  1.7  es  1.30384048104
# La raiz de  1.8  es  1.3416407865
# La raiz de  1.9  es  1.37840487521
# La raiz de  2.0  es  1.41421356237
# La raiz de  2.1  es  1.44913767462
# La raiz de  2.2  es  1.48323969742
# La raiz de  2.3  es  1.51657508881
# La raiz de  2.4  es  1.54919333848
# La raiz de  2.5  es  1.58113883008
# La raiz de  2.6  es  1.61245154966
# ...

# %% [markdown]
# **2.** Considera la fórmula de recursión $ x_{n+1} = x_n^2 $.
#
# a. ¿Cuál es el valor del iterado $x_{75}$ cuando el valor inicial es $x_0=1-10^{-20}$, calculado numéricamente?
#
# b. Compara el resultado numérico obtenido con el que uno esperaría al elevar al cuadrado un número ligeramente menor que 1 un
# montón de veces... ¿Cuál resultado es el correcto?
#
# c. ¿Qué necesitarías para verificar esto numéricamente?
#
# d. Suele ser una buena idea hacer el código más general posible, para no repetir esfuerzos después. ¿Cómo podrías escribir código para la iteración general $x_{n+1} = f(x_n)$, donde $f$ es una función dada (una función implementada con `def` en Python)?

# %% [markdown]
# ### Respuestas al problema 2

# %% [markdown]
# a) Si calculamos el valor $x_{75}$ por default obtendríamos $1.0$, esto debido a que Python sólo nos deja manejar operaciones de hasta 17 decimales en nuestras variables de punto flotante. Sin embargo, gracias al uso de la librería mpmath podemos hacer que Python use más dígitos significativos en sus operaciones, por lo que después de hacer esos cambios obtenemos que el valor de $x_{75} =$ 1.913762494511178402243909e-1641, o sea, prácticamente cero.

# %% [markdown]
# b) Cualquier valor exponenciado al cuadrado en el intervalo $(0,1)$ será menor que el valor mismo ($ x > x^2$ | $x \in (0,1)$), por lo que es lógico asumir que conforme se itera muchas veces el valor, éste se hace más y más pequeño hasta tender a cero. Lo cual significa que ambos resultados son correctos, y que después de realizar el método muchas veces el valor converge a cero.

# %% [markdown]
# c) Se puede variar el valor inicial del método para comprobar que en efecto, entre más pequeño sea éste, más rápido va a llegar a cero.

# %% [markdown]
# d) A continuación se mostrará el código utilizado en este problema. Aquí podremos ver que se crearon dos funciones, una que calcula la recursión recibiendo el valor inicial $x0$ y el número total de iteraciones $n$, y otra que es precisamente la que estipula la función a realizar en la recursión.

# %% [markdown]
# ### Código del problema 2

# %%
import numpy as np

ini = 4
fin = 250

def calcula_pi(n):
	R = 1
	alfa = 2*np.pi/n
	lado_in = np.sqrt(2.0-2.0*np.cos(alfa))
	per_in = lado_in*n
	pi_in = per_in/2
	
	betta = (np.pi-alfa)/2.0
	betta_comp = np.pi/2 - betta
	lado_out = lado_in * 1/np.cos(betta_comp)
	per_out = lado_out*n
	pi_out = per_out/2
	
	print "n = ", n, "lim inf: ", pi_in, " lim_sup: ", pi_out
	return pi_in, pi_out

X = np.array([calcula_pi(n) for n in range(ini,fin)])
pi_int = X[:,0]
pi_ext = X[:,1]

x = range(ini,fin)

from matplotlib import pyplot as plt
plt.figure()
plt.ion()
plt.plot(x,pi_int,'o-')
plt.plot(x,pi_ext,'o-')
plt.xlabel("$n$ - lados del poligono")
plt.title("calculo de $\pi$ por metodo de Arquimides")
plt.grid(True)
plt.show()

error_int = pi_int - np.pi
error_ext = pi_ext - np.pi

plt.figure()
plt.grid(True)
plt.xlabel("$n$ - lados del poligono")
plt.ylabel("$\epsilon_n$",fontsize=18)
plt.title("Error de la cota inferior")
plt.plot(x,error_int)

plt.figure()
plt.grid(True)
plt.xlabel("$n$ - lados del poligono")
plt.ylabel("$\epsilon_n$",fontsize=18)
plt.title("Error de la cota superior")
plt.plot(x,error_ext)

x = np.array(x)

plt.figure()
plt.loglog(x,np.abs(error_int),'o')
plt.xlabel("$n$ - lados del poligono")
plt.ylabel("$\epsilon_n$",fontsize=18)
plt.title("Error de la cota inferior (escala logaritmica)")
plt.loglog(x, (1/np.pi)**(-3./2.)*x**(-2.),'-')
plt.grid(True)

plt.figure()
plt.loglog(x,np.abs(error_ext),'o')
plt.xlabel("$n$ - lados del poligono")
plt.ylabel("$\epsilon_n$",fontsize=18)
plt.title("Error de la cota superior (escala logaritmica)")
plt.loglog(x, (1/np.pi*x)**(-2.),'-')
plt.grid(True)
import numpy as np
from sympy.mpmath import *

mp.dps = 25

def funcion(x0):
	return x0**2

def recursion(x0,n):
	for i in xrange(n):
		x1 = funcion(x0)
		x0 = x1;
		print "el valor ", i+1," es", x1
	return
	
n  = 75
a = mpf(1)
b = mpf(10e-20)
x0 = a-b

recursion(x0,n)
# Out:
# n =  4 lim inf:  2.82842712475  lim_sup:  4.0
# n =  5 lim inf:  2.93892626146  lim_sup:  3.63271264003
# n =  6 lim inf:  3.0  lim_sup:  3.46410161514
# n =  7 lim inf:  3.03718617382  lim_sup:  3.37102233165
# n =  8 lim inf:  3.06146745892  lim_sup:  3.31370849898
# n =  9 lim inf:  3.07818128993  lim_sup:  3.2757321084
# n =  10 lim inf:  3.09016994375  lim_sup:  3.24919696233
# n =  11 lim inf:  3.09905812526  lim_sup:  3.22989142232
# n =  12 lim inf:  3.10582854123  lim_sup:  3.21539030917
# n =  13 lim inf:  3.11110363574  lim_sup:  3.20421221942
# n =  14 lim inf:  3.11529307539  lim_sup:  3.19540864146
# n =  15 lim inf:  3.11867536227  lim_sup:  3.18834842505
# n =  16 lim inf:  3.12144515226  lim_sup:  3.18259787807
# n =  17 lim inf:  3.12374180288  lim_sup:  3.17785075084
# n =  18 lim inf:  3.125667198  lim_sup:  3.17388565275
# n =  19 lim inf:  3.12729721533  lim_sup:  3.17053923805
# n =  20 lim inf:  3.1286893008  lim_sup:  3.16768880649
# ...

# %% [markdown]
# **3.** *"Hace muchos muchos años, en un reino muy lejano..."*, se le ocurrió a Arquímedes un método para determinar el valor numérico de $\pi$. El método consiste en considerar dos polígonos regulares de $n$ lados, uno inscrito y otro circunscrito al círculo, y ver cómo el área de estos acota por abajo y arriba el área del círculo.
#
# a. Da las cotas (inferior y superior) al área del círculo de radio 1, *al menos* cuando $n=4$, $5$ y $6$ (o sea, las cotas que se obtienen usando los siguientes polígonos regulares:  el cuadrado, el pentágono y el hexágono).
#
# [Arquímedes seguramente hizo esto de manera empírica, construyendo los polígonos; para este ejercicio se
# vale utilizar lo que sabes de geometría y trigonometría.]
#
# b. ¿Se te ocurre cómo obtener las cotas para $\pi$ usando un polígono regular de $n$ lados?
#
# (Éste es el **Ejercicio 1.1** del Moore-Kearfortt (2009); la solución que ellos dan para $n=4$ me parece que está mal en la cota inferior.)

# %% [markdown]
# ### Respuestas del problema 3

# %% [markdown]
# a) Para encontrar las cotas inferior y superior de $\pi$ para $n = 4$ , $5$ y $6$... fue necesario hacer un análisis trigonométrico haciendo uso de la ley de cosenos. Es importante notar que para cuando $n$ es múltiplo de $4$ no es necesario hacer uso de la ley de cosenos, pues los ángulos interiores del polígono hacen que el análisis se reduzca a sólo usar el teorema de Pitágoras. Se escribió una función en Python que calcula las cotas dado $n$ (importante notar que $n$ debe ser igual o mayor a 4).

# %% [raw]
# n =  4 lim inf:  2.82842712475  lim_sup:  4.0
# n =  5 lim inf:  2.93892626146  lim_sup:  3.63271264003
# n =  6 lim inf:  3.0  lim_sup:  3.46410161514
# n =  7 lim inf:  3.03718617382  lim_sup:  3.37102233165
# n =  8 lim inf:  3.06146745892  lim_sup:  3.31370849898
# n =  9 lim inf:  3.07818128993  lim_sup:  3.2757321084
# n =  10 lim inf:  3.09016994375  lim_sup:  3.24919696233
# n =  11 lim inf:  3.09905812526  lim_sup:  3.22989142232
# n =  12 lim inf:  3.10582854123  lim_sup:  3.21539030917
# n =  13 lim inf:  3.11110363574  lim_sup:  3.20421221942
# n =  14 lim inf:  3.11529307539  lim_sup:  3.19540864146
# n =  15 lim inf:  3.11867536227  lim_sup:  3.18834842505
# n =  16 lim inf:  3.12144515226  lim_sup:  3.18259787807
# n =  17 lim inf:  3.12374180288  lim_sup:  3.17785075084
# n =  18 lim inf:  3.125667198  lim_sup:  3.17388565275
# n =  19 lim inf:  3.12729721533  lim_sup:  3.17053923805
# n =  20 lim inf:  3.1286893008  lim_sup:  3.16768880649
# n =  21 lim inf:  3.1298875897  lim_sup:  3.16524071327
# n =  22 lim inf:  3.13092644201  lim_sup:  3.16312246789
# n =  23 lim inf:  3.13183292921  lim_sup:  3.16127723598
# n =  24 lim inf:  3.13262861328  lim_sup:  3.1596599421
# n =  25 lim inf:  3.13333083911  lim_sup:  3.15823446115

# %% [markdown]
# b) Sí. Precisamente usando un poco de trigonometría y analizando las propiedades de cada polígono y generalizándolas para cualquier $n$. En el código que se presenta más delante se puede comprobar cómo se calcularon las cotas de $\pi$.

# %% [markdown]
# Adicionalmente se hizo un análisis para ver qué tan rápido converge la secuencia de las cotas de $\pi$. A base de un método gráfico y prueba y error se encontró que para la cota inferior la serie converge a una 'velocidad' de $\pi^{3/2}n^{-2}$ y la cota superior a $\pi^{2}n^{-2}$. Aunque no se tiene seguridad que el valor sea exactamente ese, se puede verificar las gráficas logarítmicas en el código.

# %% [markdown]
# ### Código y gráficas del problema 3

# %%
# %matplotlib inline

# %%
import numpy as np

ini = 4
fin = 100

def calcula_pi(n):
	R = 1
	alfa = 2*np.pi/n
	lado_in = np.sqrt(2.0-2.0*np.cos(alfa))
	per_in = lado_in*n
	pi_in = per_in/2
	
	betta = (np.pi-alfa)/2.0
	betta_comp = np.pi/2 - betta
	lado_out = lado_in * 1/np.cos(betta_comp)
	per_out = lado_out*n
	pi_out = per_out/2
	
	print "n = ", n, "lim inf: ", pi_in, " lim_sup: ", pi_out
	return pi_in, pi_out

X = np.array([calcula_pi(n) for n in range(ini,fin)])
pi_int = X[:,0]
pi_ext = X[:,1]

x = range(ini,fin)
# Out:
# n =  4 lim inf:  2.82842712475  lim_sup:  4.0
# n =  5 lim inf:  2.93892626146  lim_sup:  3.63271264003
# n =  6 lim inf:  3.0  lim_sup:  3.46410161514
# n =  7 lim inf:  3.03718617382  lim_sup:  3.37102233165
# n =  8 lim inf:  3.06146745892  lim_sup:  3.31370849898
# n =  9 lim inf:  3.07818128993  lim_sup:  3.2757321084
# n =  10 lim inf:  3.09016994375  lim_sup:  3.24919696233
# n =  11 lim inf:  3.09905812526  lim_sup:  3.22989142232
# n =  12 lim inf:  3.10582854123  lim_sup:  3.21539030917
# n =  13 lim inf:  3.11110363574  lim_sup:  3.20421221942
# n =  14 lim inf:  3.11529307539  lim_sup:  3.19540864146
# n =  15 lim inf:  3.11867536227  lim_sup:  3.18834842505
# n =  16 lim inf:  3.12144515226  lim_sup:  3.18259787807
# n =  17 lim inf:  3.12374180288  lim_sup:  3.17785075084
# n =  18 lim inf:  3.125667198  lim_sup:  3.17388565275
# n =  19 lim inf:  3.12729721533  lim_sup:  3.17053923805
# n =  20 lim inf:  3.1286893008  lim_sup:  3.16768880649
# ...

# %%
from matplotlib import pyplot as plt
plt.figure()
plt.ion()
plt.plot(x,pi_int,'o-')
plt.plot(x,pi_ext,'o-')
plt.xlabel("$n$ - lados del poligono")
plt.title("calculo de $\pi$ por metodo de Arquimides")
plt.grid(True)
plt.show()

error_int = pi_int - np.pi
error_ext = pi_ext - np.pi

# %%
plt.figure()
plt.grid(True)
plt.xlabel("$n$ - lados del poligono")
plt.ylabel("$\epsilon_n$",fontsize=18)
plt.title("Error de la cota inferior")
plt.plot(x,error_int)

# %%
plt.figure()
plt.grid(True)
plt.xlabel("$n$ - lados del poligono")
plt.ylabel("$\epsilon_n$",fontsize=18)
plt.title("Error de la cota superior")
plt.plot(x,error_ext)

# %%
x = np.array(x)

plt.figure()
plt.loglog(x,np.abs(error_int),'o')
plt.xlabel("$n$ - lados del poligono")
plt.ylabel("$\epsilon_n$",fontsize=18)
plt.title("Error de la cota inferior (escala logaritmica)")
plt.loglog(x, x**(-2.),'-')
plt.grid(True)

# %%
plt.figure()
plt.loglog(x,np.abs(error_ext),'o')
plt.xlabel("$n$ - lados del poligono")
plt.ylabel("$\epsilon_n$",fontsize=18)
plt.title("Error de la cota superior (escala logaritmica)")
plt.loglog(x, (1/np.pi*x)**(-2.),'-')
plt.grid(True)
